# %%
# !pip install librosa
# !pip install IPython.display
# Out:
# Requirement already satisfied: librosa in c:\users\kon-boot\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (4.4.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (1.16.4)
# Requirement already satisfied: joblib>=0.12 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (0.13.2)
# Requirement already satisfied: six>=1.3 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (1.2.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: soundfile>=0.9.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (0.10.2)
# Requirement already satisfied: numba>=0.43.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (0.44.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (0.21.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from librosa) (2.1.8)
# Requirement already satisfied: cffi>=1.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.12.3)
# Requirement already satisfied: llvmlite>=0.29.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.29.0)
# Requirement already satisfied: pycparser in c:\users\kon-boot\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.19)
# Collecting IPython.display
#   ERROR: Could not find a version that satisfies the requirement IPython.display (from versions: none)
# ERROR: No matching distribution found for IPython.display

# %%
import IPython.display as ipd
import librosa, librosa.display
x, sr = librosa.load('UrbanSound8K/audio/fold9/99500-2-0-50.wav')

ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
# Class: Children playing 
filename = 'UrbanSound8K/audio/fold9/99500-2-0-50.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
_ = librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Class: engine_idling 


filename = 'UrbanSound8K/audio/fold3/6988-5-0-1.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
_ = librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd
metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata["class"].value_counts()
# Out:
# air_conditioner     1000
# engine_idling       1000
# drilling            1000
# dog_bark            1000
# jackhammer          1000
# street_music        1000
# children_playing    1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
# Load various imports 
import pandas as pd
import os
import librosa
import librosa.display

from wavfilehelper import WavFileHelper
wavfilehelper = WavFileHelper()

audiodata = []
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath('UrbanSound8K/audio/'),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    data = wavfilehelper.read_file_properties(file_name)
    audiodata.append(data)

# Convert into a Panda dataframe
audiodf = pd.DataFrame(audiodata, columns=['num_channels','sample_rate','bit_depth'])

# %%
# num of channels === le nombre de canaux audio
print(audiodf.num_channels.value_counts(normalize=True))
# Out:
# 2    0.915369
# 1    0.084631
# Name: num_channels, dtype: float64

# %%
# sample rates ===la fréquence d'échantillonnage

print(audiodf.sample_rate.value_counts(normalize=True))
# Out:
# 44100     0.614979
# 48000     0.286532
# 96000     0.069858
# 24000     0.009391
# 16000     0.005153
# 22050     0.005039
# 11025     0.004466
# 192000    0.001947
# 8000      0.001374
# 11024     0.000802
# 32000     0.000458
# Name: sample_rate, dtype: float64

# %%
# bit depth=== résolution en bits

print(audiodf.bit_depth.value_counts(normalize=True))
# Out:
# 16    0.659414
# 24    0.315277
# 32    0.019354
# 8     0.004924
# 4     0.001031
# Name: bit_depth, dtype: float64

# %%
import librosa 
from scipy.io import wavfile as wav
import numpy as np

filename = 'UrbanSound8K/audio/fold9/99500-2-0-50.wav' 

librosa_audio, librosa_sample_rate = librosa.load(filename) 
scipy_sample_rate, scipy_audio = wav.read(filename) 

print('Original sample rate:', scipy_sample_rate) 
print('Librosa sample rate:', librosa_sample_rate)
# Out:
# Original sample rate: 44100
# Librosa sample rate: 22050

# %%
print('Original audio file min~max range:', np.min(scipy_audio), 'to', np.max(scipy_audio))
print('Librosa audio file min~max range:', np.min(librosa_audio), 'to', np.max(librosa_audio))
# Out:
# Original audio file min~max range: -1766 to 1528
# Librosa audio file min~max range: -0.03491252 to 0.03701195

# %%
import matplotlib.pyplot as plt
# Original audio with 2 channels 
plt.figure(figsize=(12, 4))
plt.plot(scipy_audio)
# Out:
# [<matplotlib.lines.Line2D at 0x1a4124eaf28>,
#  <matplotlib.lines.Line2D at 0x1a4124fa940>]

# %%
# Librosa audio with channels merged 
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 173)

# %%
import librosa.display
librosa.display.specshow(mfccs, sr=librosa_sample_rate, x_axis='time')

# %%
def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
    return mfccsscaled

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
fulldatasetpath = 'UrbanSound8K/audio'

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    class_label = row["class"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# Finished feature extraction from  8732  files

# %%
# !pip install keras
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))
# Out:
# Collecting keras
#   Using cached https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (1.2.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (1.16.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: h5py in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: pyyaml in c:\users\kon-boot\anaconda3\lib\site-packages (from keras) (5.1.1)
# Installing collected packages: keras
# Successfully installed keras-2.3.1
# Using TensorFlow backend.

# %%
# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
### store the preprocessed data for use in the next notebook

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 
# %store yy 
# %store le
# Out:
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)

# %% [markdown]
# ## Model Training
# ### MLP(MultiLayer Perceeption)

# %%
#Load Preprocessed data¶
# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %%
#Initial model architecture - MLP(Multilayer Perceptron )
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               10496
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 78,858
# Trainable params: 78,858
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 14.1958%

# %%
#Training
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/100
# 6985/6985 [==============================] - 1s 113us/step - loss: 2.3180 - accuracy: 0.2135 - val_loss: 2.0450 - val_accuracy: 0.3045
#
# Epoch 00001: val_loss improved from inf to 2.04505, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 6985/6985 [==============================] - 1s 108us/step - loss: 2.0866 - accuracy: 0.2620 - val_loss: 1.9012 - val_accuracy: 0.3549
#
# Epoch 00002: val_loss improved from 2.04505 to 1.90121, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 3/100
# 6985/6985 [==============================] - 1s 111us/step - loss: 1.9838 - accuracy: 0.3014 - val_loss: 1.7549 - val_accuracy: 0.3835
#
# Epoch 00003: val_loss improved from 1.90121 to 1.75491, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 4/100
# 6985/6985 [==============================] - 1s 120us/step - loss: 1.8749 - accuracy: 0.3298 - val_loss: 1.6815 - val_accuracy: 0.4133
#
# Epoch 00004: val_loss improved from 1.75491 to 1.68154, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 5/100
# 6985/6985 [==============================] - 1s 135us/step - loss: 1.7951 - accuracy: 0.3585 - val_loss: 1.5438 - val_accuracy: 0.4568
#
# Epoch 00005: val_loss improved from 1.68154 to 1.54381, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 6/100
# 6985/6985 [==============================] - 1s 117us/step - loss: 1.6903 - accuracy: 0.4017 - val_loss: 1.5114 - val_accuracy: 0.4728
#
# Epoch 00006: val_loss improved from 1.54381 to 1.51145, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 7/100
# 6985/6985 [==============================] - 1s 124us/step - loss: 1.6257 - accuracy: 0.4271 - val_loss: 1.3917 - val_accuracy: 0.5701
#
# Epoch 00007: val_loss improved from 1.51145 to 1.39174, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 8/100
# 6985/6985 [==============================] - 1s 128us/step - loss: 1.5355 - accuracy: 0.4618 - val_loss: 1.2944 - val_accuracy: 0.5907
#
# Epoch 00008: val_loss improved from 1.39174 to 1.29440, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 9/100
# 6985/6985 [==============================] - 1s 119us/step - loss: 1.4597 - accuracy: 0.4825 - val_loss: 1.2424 - val_accuracy: 0.6102
#
# Epoch 00009: val_loss improved from 1.29440 to 1.24244, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 10/100
# 6985/6985 [==============================] - ETA: 0s - loss: 1.3805 - accuracy: 0.52 - 1s 108us/step - loss: 1.3813 - accuracy: 0.5257 - val_loss: 1.1598 - val_accuracy: 0.6308
#
# Epoch 00010: val_loss improved from 1.24244 to 1.15977, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 11/100
# 6985/6985 [==============================] - 1s 113us/step - loss: 1.3280 - accuracy: 0.5390 - val_loss: 1.1019 - val_accuracy: 0.6497
#
# Epoch 00011: val_loss improved from 1.15977 to 1.10194, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 12/100
# 6985/6985 [==============================] - 1s 111us/step - loss: 1.2713 - accuracy: 0.5675 - val_loss: 1.0453 - val_accuracy: 0.6606
#
# Epoch 00012: val_loss improved from 1.10194 to 1.04533, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 13/100
# 6985/6985 [==============================] - 1s 100us/step - loss: 1.2031 - accuracy: 0.5870 - val_loss: 0.9885 - val_accuracy: 0.6955
#
# Epoch 00013: val_loss improved from 1.04533 to 0.98845, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 14/100
# 6985/6985 [==============================] - 1s 105us/step - loss: 1.1658 - accuracy: 0.6026 - val_loss: 0.9519 - val_accuracy: 0.7001
#
# Epoch 00014: val_loss improved from 0.98845 to 0.95189, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 15/100
# 6985/6985 [==============================] - 1s 104us/step - loss: 1.1347 - accuracy: 0.6047 - val_loss: 0.8891 - val_accuracy: 0.7224
#
# Epoch 00015: val_loss improved from 0.95189 to 0.88907, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 16/100
# 6985/6985 [==============================] - 1s 117us/step - loss: 1.0792 - accuracy: 0.6342 - val_loss: 0.8430 - val_accuracy: 0.7401
#
# Epoch 00016: val_loss improved from 0.88907 to 0.84303, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch
100
# 6985/6985 [==============================] - 1s 117us/step - loss: 0.5354 - accuracy: 0.8220 - val_loss: 0.4010 - val_accuracy: 0.8838
#
# Epoch 00090: val_loss improved from 0.41420 to 0.40099, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 91/100
# 6985/6985 [==============================] - 1s 119us/step - loss: 0.5366 - accuracy: 0.8188 - val_loss: 0.4450 - val_accuracy: 0.8718
#
# Epoch 00091: val_loss did not improve from 0.40099
# Epoch 92/100
# 6985/6985 [==============================] - 1s 124us/step - loss: 0.5069 - accuracy: 0.8265 - val_loss: 0.4184 - val_accuracy: 0.8775
#
# Epoch 00092: val_loss did not improve from 0.40099
# Epoch 93/100
# 6985/6985 [==============================] - 1s 117us/step - loss: 0.5364 - accuracy: 0.8218 - val_loss: 0.4197 - val_accuracy: 0.8809
#
# Epoch 00093: val_loss did not improve from 0.40099
# Epoch 94/100
# 6985/6985 [==============================] - 1s 110us/step - loss: 0.5495 - accuracy: 0.8175 - val_loss: 0.4317 - val_accuracy: 0.8695
#
# Epoch 00094: val_loss did not improve from 0.40099
# Epoch 95/100
# 6985/6985 [==============================] - 1s 125us/step - loss: 0.5294 - accuracy: 0.8226 - val_loss: 0.4421 - val_accuracy: 0.8832
#
# Epoch 00095: val_loss did not improve from 0.40099
# Epoch 96/100
# 6985/6985 [==============================] - 1s 132us/step - loss: 0.5272 - accuracy: 0.8220 - val_loss: 0.4552 - val_accuracy: 0.8764
#
# Epoch 00096: val_loss did not improve from 0.40099
# Epoch 97/100
# 6985/6985 [==============================] - 1s 129us/step - loss: 0.5039 - accuracy: 0.8286 - val_loss: 0.4383 - val_accuracy: 0.8804
#
# Epoch 00097: val_loss did not improve from 0.40099
# Epoch 98/100
# 6985/6985 [==============================] - 1s 110us/step - loss: 0.5191 - accuracy: 0.8309 - val_loss: 0.4224 - val_accuracy: 0.8752
#
# Epoch 00098: val_loss did not improve from 0.40099
# Epoch 99/100
# 6985/6985 [==============================] - 1s 112us/step - loss: 0.5092 - accuracy: 0.8308 - val_loss: 0.4593 - val_accuracy: 0.8746
#
# Epoch 00099: val_loss did not improve from 0.40099
# Epoch 100/100
# 6985/6985 [==============================] - 1s 133us/step - loss: 0.5181 - accuracy: 0.8239 - val_loss: 0.4317 - val_accuracy: 0.8695
#
# Epoch 00100: val_loss did not improve from 0.40099
# Training completed in time:  0:01:24.132323

# %%
#Test the model
# Evaluer le model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9258410930633545
# Testing Accuracy:  0.8694905638694763

# %%
#Comme il n'y a pas une grande différence entre les scores de training et de test (~ 5%), cela suggère que le modèle ne souffre pas d'overffiting

# %% [markdown]
# ## prédiction

# %%
#Ici, nous allons construire une méthode qui nous permettra de tester les prédictions de modèles sur un fichier audio .wav spécifié.
import librosa 
import numpy as np 

def extract_feature(file_name):
   
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None

    return np.array([mfccsscaled])

# %%
def print_prediction(file_name):
    prediction_feature = extract_feature(file_name) 

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %% [markdown]
# ## Validation

# %% [markdown]
# ###### 1.valider avec des exemples de données

# %%
# Class: Children playing 
filename = 'UrbanSound8K/audio/fold9/99500-2-0-50.wav'
print_prediction(filename)
# Out:
# The predicted class is: children_playing
#
# air_conditioner 		 :  0.00002444308302074205130338668823
# car_horn 		 :  0.00000190390596799261402338743210
# children_playing 		 :  0.98706132173538208007812500000000
# dog_bark 		 :  0.00884074345231056213378906250000
# drilling 		 :  0.00062392995459958910942077636719
# engine_idling 		 :  0.00027677958132699131965637207031
# gun_shot 		 :  0.00014893081970512866973876953125
# jackhammer 		 :  0.00000000551704992801660409895703
# siren 		 :  0.00108367565553635358810424804688
# street_music 		 :  0.00193805829621851444244384765625

# %%
# Class: engine_idling 

filename = 'UrbanSound8K/audio/fold3/6988-5-0-1.wav'
print_prediction(filename)
# Out:
# The predicted class is: engine_idling
#
# air_conditioner 		 :  0.00004792590698343701660633087158
# car_horn 		 :  0.00734776630997657775878906250000
# children_playing 		 :  0.02517339959740638732910156250000
# dog_bark 		 :  0.01227040123194456100463867187500
# drilling 		 :  0.00000005905241451387155393604189
# engine_idling 		 :  0.88281828165054321289062500000000
# gun_shot 		 :  0.00025762539007700979709625244141
# jackhammer 		 :  0.00000000000476671003016293504118
# siren 		 :  0.00023601006250828504562377929688
# street_music 		 :  0.07184852659702301025390625000000

# %% [markdown]
# #### 2. valider avec d'autre audio

# %%
filename = 'Evaluation audio/dog_bark_1.wav'
print_prediction(filename)
# Out:
# The predicted class is: dog_bark
#
# air_conditioner 		 :  0.00170126324519515037536621093750
# car_horn 		 :  0.00386084592901170253753662109375
# children_playing 		 :  0.05400890856981277465820312500000
# dog_bark 		 :  0.47950816154479980468750000000000
# drilling 		 :  0.01919531635940074920654296875000
# engine_idling 		 :  0.00011006562999682500958442687988
# gun_shot 		 :  0.12952058017253875732421875000000
# jackhammer 		 :  0.00002369907815591432154178619385
# siren 		 :  0.03513796254992485046386718750000
# street_music 		 :  0.27693316340446472167968750000000

# %%
filename = 'Evaluation audio/drilling_1.wav'
print_prediction(filename)
# Out:
# The predicted class is: jackhammer
#
# air_conditioner 		 :  0.21988007426261901855468750000000
# car_horn 		 :  0.00000448590799351222813129425049
# children_playing 		 :  0.00009731154568726196885108947754
# dog_bark 		 :  0.00000189293200492102187126874924
# drilling 		 :  0.12620775401592254638671875000000
# engine_idling 		 :  0.00000326281747220491524785757065
# gun_shot 		 :  0.01945782825350761413574218750000
# jackhammer 		 :  0.63433897495269775390625000000000
# siren 		 :  0.00000163157585575390839949250221
# street_music 		 :  0.00000679997083352645859122276306

# %%
filename = 'Evaluation audio/gun_shot_1.wav'
print_prediction(filename)
# Out:
# The predicted class is: street_music
#
# air_conditioner 		 :  0.05966595560312271118164062500000
# car_horn 		 :  0.00068839627783745527267456054688
# children_playing 		 :  0.00360774667933583259582519531250
# dog_bark 		 :  0.43091210722923278808593750000000
# drilling 		 :  0.00108278030529618263244628906250
# engine_idling 		 :  0.00400716811418533325195312500000
# gun_shot 		 :  0.04638382419943809509277343750000
# jackhammer 		 :  0.00000843192992761032655835151672
# siren 		 :  0.00430741533637046813964843750000
# street_music 		 :  0.44933620095252990722656250000000

# %%
filename = 'Evaluation audio/siren_1.wav'
print_prediction(filename)
# Out:
# The predicted class is: engine_idling
#
# air_conditioner 		 :  0.00234786258079111576080322265625
# car_horn 		 :  0.00214495602995157241821289062500
# children_playing 		 :  0.12218851596117019653320312500000
# dog_bark 		 :  0.25852471590042114257812500000000
# drilling 		 :  0.00147248047869652509689331054688
# engine_idling 		 :  0.30491453409194946289062500000000
# gun_shot 		 :  0.01752706803381443023681640625000
# jackhammer 		 :  0.00099768838845193386077880859375
# siren 		 :  0.25742307305335998535156250000000
# street_music 		 :  0.03245908766984939575195312500000

# %% [markdown]
# ## Model Training
# ### CNN( Convolutional Neural Network)

# %%
# Load preprocessed data

# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %%
import numpy as np
max_pad_len = 174

def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccs

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
fulldatasetpath = 'UrbanSound8K/audio/'

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    class_label = row["class"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# Finished feature extraction from  8732  files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_rows = 40
num_columns = 174
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 39, 173, 16)       80
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 20, 64)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 19, 128)        32896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 9, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 9, 128)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 44,602
# Trainable params: 44,602
# Non-trainable params: 0
# _________________________________________________________________
# 1747/1747 [==============================] - 6s 3ms/step
# Pre-training accuracy: 5.2662%

# %% [markdown]
# ### training cnn model

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

#num_epochs = 12
#num_batch_size = 128

num_epochs = 72
num_batch_size = 256

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_cnn.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/72
# 6985/6985 [==============================] - 45s 6ms/step - loss: 3.9128 - accuracy: 0.2060 - val_loss: 2.0742 - val_accuracy: 0.2753
#
# Epoch 00001: val_loss improved from inf to 2.07418, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 2/72
# 6985/6985 [==============================] - 34s 5ms/step - loss: 1.8100 - accuracy: 0.3558 - val_loss: 1.8622 - val_accuracy: 0.3795
#
# Epoch 00002: val_loss improved from 2.07418 to 1.86220, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 3/72
# 6985/6985 [==============================] - 34s 5ms/step - loss: 1.5423 - accuracy: 0.4587 - val_loss: 1.6714 - val_accuracy: 0.4207
#
# Epoch 00003: val_loss improved from 1.86220 to 1.67138, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 4/72
# 6985/6985 [==============================] - 35s 5ms/step - loss: 1.4119 - accuracy: 0.5042 - val_loss: 1.5707 - val_accuracy: 0.4448
#
# Epoch 00004: val_loss improved from 1.67138 to 1.57067, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 5/72
# 6985/6985 [==============================] - 36s 5ms/step - loss: 1.2956 - accuracy: 0.5496 - val_loss: 1.4772 - val_accuracy: 0.5031
#
# Epoch 00005: val_loss improved from 1.57067 to 1.47724, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 6/72
# 6985/6985 [==============================] - 35s 5ms/step - loss: 1.2311 - accuracy: 0.5684 - val_loss: 1.3795 - val_accuracy: 0.5415
#
# Epoch 00006: val_loss improved from 1.47724 to 1.37945, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 7/72
# 6985/6985 [==============================] - 33s 5ms/step - loss: 1.1720 - accuracy: 0.5865 - val_loss: 1.3257 - val_accuracy: 0.5701
#
# Epoch 00007: val_loss improved from 1.37945 to 1.32572, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 8/72
# 6985/6985 [==============================] - 36s 5ms/step - loss: 1.1131 - accuracy: 0.6146 - val_loss: 1.2579 - val_accuracy: 0.5833
#
# Epoch 00008: val_loss improved from 1.32572 to 1.25794, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 9/72
# 6985/6985 [==============================] - 42s 6ms/step - loss: 1.0665 - accuracy: 0.6306 - val_loss: 1.2032 - val_accuracy: 0.6056
#
# Epoch 00009: val_loss improved from 1.25794 to 1.20319, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 10/72
# 6985/6985 [==============================] - 41s 6ms/step - loss: 1.0172 - accuracy: 0.6478 - val_loss: 1.1335 - val_accuracy: 0.6285
#
# Epoch 00010: val_loss improved from 1.20319 to 1.13349, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 11/72
# 6985/6985 [==============================] - 40s 6ms/step - loss: 0.9638 - accuracy: 0.6634 - val_loss: 1.0984 - val_accuracy: 0.6377
#
# Epoch 00011: val_loss improved from 1.13349 to 1.09845, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 12/72
# 6985/6985 [==============================] - 38s 5ms/step - loss: 0.9409 - accuracy: 0.6790 - val_loss: 1.0618 - val_accuracy: 0.6554
#
# Epoch 00012: val_loss improved from 1.09845 to 1.06182, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 13/72
# 6985/6985 [==============================] - 40s 6ms/step - loss: 0.8873 - accuracy: 0.7002 - val_loss: 1.0148 - val_accuracy: 0.6525
#
# Epoch 00013: val_loss improved from 1.06182 to 1.01481, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 14/72
# 6985/6985 [==============================] - 41s 6ms/step - loss: 0.8638 - accuracy: 0.7029 - val_loss: 0.9886 - val_accuracy: 0.6732
#
# Epoch 00014: val_loss improved from 1.01481 to 0.98859, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 15/72
# 6985/6985 [==============================] - 45s 6ms/step - loss: 0.8346 - accuracy: 0.7125 - val_loss: 1.0139 - val_accuracy: 0.6508
#
# Epoch 00015: val_loss did not improve from 0.98859
# Epoch 16/72
# 6985/6985 [==============================] - 48s 7ms/step - loss: 0.8006 - accuracy: 0.7243 - val_loss: 0.9309 - val_accuracy: 0.6875
#
# Epoch 00016: val_loss improved from 0.98859 to 0.93089, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 17/72
# 6985/6985 [==============================] - 51s 7ms/step - loss: 0.7819 - accuracy: 0.7288 - val_loss: 0.9279 - val_accuracy: 0.6949
#
# Epoch 00017: val_loss improved from 0.93089 to 0.92789, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 18/72
# 6985/6985 [==============================] - 46s 7ms/step - loss: 0.7730 - accuracy: 0.7333 - val_loss: 0.9185 - val_accuracy: 0.6898
#
# Epoch 00018: val_loss improved from 0.92789 to 0.91854, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 19/72
# 6985/6985 [==============================] - 47s 7ms/step - loss: 0.7357 - accuracy: 0.7469 - val_loss: 0.8807 - val_accuracy: 0.7178
#
# Epoch 00019: val_loss improved from 0.91854 to 0.88067, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 20/72
# 6985/6985 [==============================] - 44s 6ms/step - loss: 0.7208 - accuracy: 0.7485 - val_loss: 0.8919 - val_accuracy: 0.7092
#
# Epoch 00020: val_loss did not improve from 0.88067
# Epoch 21/72
# 6985/6985 [==============================] - 46s 7ms/step - loss: 0.6926 - accuracy: 0.7635 - val_loss: 0.8468 - val_accuracy: 0.7178
#
# Epoch 00021: val_loss improved from 0.88067 to 0.84678, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 22/72
# 6985/6985 [==============================] - 42s 6ms/step - loss: 0.6669 - accuracy: 0.7662 - val_loss: 0.8147 - val_accuracy: 0.7304
#
# Epoch 00022: val_loss improved from 0.84678 to 0.81468, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 23/72
# 6985/6985 [==============================] - 42s 6ms/step - loss: 0.6484 - accuracy: 0.7775 - val_loss: 0.7669 - val_accuracy: 0.7493
#
# Epoch 00023: val_loss improved from 0.81468 to 0.76687, saving model to saved_models/weights.best.basic_cnn.hdf5
# Epoch 24/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6448 - accuracy: 0.7811
